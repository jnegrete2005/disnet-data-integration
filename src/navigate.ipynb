# %%
# Make the PYTHONPATH the root directory of the project on the notebook
import os
import sys

os.chdir("..")
sys.path.append("..")

# %%
import pandas as pd

drug_combs = pd.read_csv(
    "./data/drug_combs.csv", usecols=["ID", "Drug1", "Drug2", "Cell line", "ZIP", "Bliss", "Loewe", "HSA", "classification"]
)
cell_lines = pd.read_csv("./data/cell_Line.csv")
drugs = pd.read_csv("./data/drug_chemical_info.csv", na_values=["#N/A", "none", "None", 0])

# %%
# 1. Verify Drugs
# Combine Drug1 and Drug2 into a single unique set of drugs used in combinations
used_drugs = set(drug_combs['Drug1']).union(set(drug_combs['Drug2']))
reference_drugs = set(drugs['drugName'])

# Find missing drugs (present in combs but NOT in reference list)
missing_drugs = used_drugs - reference_drugs

if len(missing_drugs) == 0:
    print("✅ All drugs in 'drug_combs' exist in the 'drugs' table.")
else:
    print(f"❌ Found {len(missing_drugs)} drugs missing from reference table:")
    print(missing_drugs)

print("-" * 30)

# 2. Verify Cell Lines
used_cells = set(drug_combs['Cell line'])
reference_cells = set(cell_lines['cellName'])

# Find missing cell lines
missing_cells = used_cells - reference_cells

if len(missing_cells) == 0:
    print("✅ All cell lines in 'drug_combs' exist in the 'cell_lines' table.")
else:
    print(f"❌ Found {len(missing_cells)} cell lines missing from reference table:")
    print(missing_cells)
# Out:
# ❌ Found 2433 drugs missing from reference table:
# {'HALOPERIDOL', 'DIHYDROARTEMISININ (DHA)', 'DRONEDARONE HCL', 'PROCHLORPERAZINE DIMALEATE', 'CEPHALOMANNINE', 'AEE788 (NVP-AEE788)', 'GSK 2250665A', 'NSC 405020', 'LY 2365109 HYDROCHLORIDE', 'LAMIVUDINE', '717906-29-1', 'CCT137690', 'TAK-632', 'METHAZOLAMIDE', 'CHEMBL3348930', 'SELUMETINIB (AZD6244)', '1169562-71-3', 'SIROLIMUS', 'ALISERTIB (MLN8237)', 'ACADESINE', 'AGN-PC-0MU5N5', 'VLX1570', 'SIRTINOL', 'ARSENIC TRIOXIDE', 'TCID', 'ZM 323881 HCL', 'METHYLTHIOURACIL', 'NCGC00162383-02', 'CORTISONE ACETATE', 'LOTEPREDNOL ETABONATE', 'HG6-64-1', '303727-31-3', 'NCGC00263108-01', 'CHEMBL1824695', 'ALFUZOSIN HCL', 'SERATRODAST', 'CHEMBL256963', 'MITOXANTRONE', 'CYROMAZINE', 'KRP-297', '8-AZAGUANINE', 'GDC-0941', 'KPT-8602', 'dimethyl but-2-enedioate', 'ZINC17545571', 'NVP-BSK805 2HCL', 'DESVENLAFAXINE', '(-)-MK 801 MALEATE', 'RIMONABANT', 'PAROXETINE HCL', '431979-47-4', 'NCGC00346563-01', 'FOSTAMATINIB (R788)', '3-methyladenine', 'SODIUM ASCORBATE', 'CAA0225', 'CHEMBL3349010', 'PRALATREXATE', 'ADEFOVIR DIPIVOXIL', 'ALVERINE CITRATE', 'ADRENALONE HCL', 'URACIL MUSTARD', 'PIROMIDIC ACID', 'ANACETRAPIB (MK-0859)', '112648-68-7', 'PFI-1 (PF-6405761)', 'FASUDIL (HA-1077) HCL', '6-(7-hydroxy-6,7-dihydro-5H-pyrrolo[1,2-c]imidazol-7-yl)-N-methyl-2-naphthamide', 'beta-Narcotine', 'SUDAHWBOROXANE-UHFFFAOYSA-N', 'MOXIFLOXACIN HCL', 'TEMPOL', 'CPEPCK INHIBITOR', 'Cobimetinib (R-enantiomer)', 'TRANEXAMIC ACID', 'Betamethasone', 'DIPHENHYDRAMINE HCL', '942487-16-3', 'suramin', 'CAMPTOTHECIN', 'LONAFARNIB', 'nifekalant', 'BRL-54443', '4-METHYLUMBELLIFERONE (4-MU)', 'SC-514', 'GW788388', 'GSK503', 'LAQUINIMOD', 'DEGRASYN (WP1130)', 'CHEMBL3348989', 'benserazide', 'AZLOCILLIN SODIUM SALT', 'CLEMASTINE FUMARATE', '200484-11-3', '891494-64-7', 'PF-299804', 'OMEPRAZOLE', 'NCGC00242502-01', 'Ralimetinib', 'BREFELDIN A', 'OXELADIN CITRATE', 'CHEMBL3188552', 'AC1NRBJE', 'OXYTETRACYCLINE (TERRAMYCIN)', 'ERK 11e', 'ZAFIRLUKAST', '218137-86-1', '1144035-53-9', 'MIGLITOL', 'SINOMENINE', 'NITAZOXANIDE', 'NCGC00253909-01', 'PD173074', 'NCGC00263268-01', 'TOPOTECAN HYDROCHLORIDE', 'BARASERTIB (AZD1152-HQPA)', 'GSK126', 'SPIRAMYCIN', 'PHLORETIN', 'UNII-7E99B9ZM19', 'EPIANDROSTERONE', 'BIBR 1532', 'DL-CARNITINE HCL', 'CA-074Me', 'CLOTRIMAZOLE', 'FORSKOLIN', 'NSC23925', 'FINGOLIMOD (FTY720) HCL', 'ISOSORBIDE', 'NIGULDIPINE', 'Go 6976', 'GYNOSTEMMA EXTRACT', 'NICORANDIL', 'DIMAPRIT 2HCL', 'GSK484', 'CILENGITIDE', 'TRIETHYLENEMELAMINE', 'MONTELUKAST SODIUM', 'SARAFLOXACIN HCL', 'JIB-04', 'MC1568', 'SAR131675', 'BESTATIN', 'CHEMBL1706858', 'BAM7', 'TERBINAFINE HCL', 'THIORIDAZINE HCL', 'MANIDIPINE', 'Siponimod', 'SITAXENTAN SODIUM', 'BEZAFIBRATE', 'CANERTINIB (CI-1033)', 'SCHEMBL17378613', 'BIO-Acetoxime', 'gm 1489', 'PF-05212384 (PKI-587)', 'URAPIDIL HCL', 'VITAMIN C', 'ZOXAZOLAMINE', 'ROCURONIUM BROMIDE', 'Fesoterodine', 'Bentamapimod', 'MEFLOQUINE', 'CHEMBL3348980', 'QUERCETIN DIHYDRATE', 'LY2784544', 'NEBIVOLOL', 'BGJ398 (NVP-BGJ398)', 'BLZ945', 'azasetron hydrochloride', 'ALFACALCIDOL', 'pd 150606', 'LUBIPROSTONE', 'HYDRALAZINE HCL', 'BET-BAY 002', 'RETAPAMULIN', 'AMOXAPINE', 'CEPHARANTHINE', 'PAEONOL', 'TALMAPIMOD', 'CHEMBL3348890', 'DEXRAZOXANE', 'KINETIN', 'KX2-391', 'PF 184', 'RIBAVIRIN', 'GELDANAMYCIN', 'ROPINIROLE HCL', 'PP2', 'PRAMOXINE HCL', 'CHEMBL178737', 'WH-4-023', 'PROGUANIL', '1439901-97-9', 'EXEMESTANE', 'LIOTHYRONINE SODIUM', 'ERIBULIN MESYLATE', 'NCGC00142624-04', 'NCGC00346737-01', 'SB 202190', 'BIOCHANIN A', 'COUMARIN', 'DOCETAXEL', 'ELETRIPTAN HBR', 'CGK 733', 'CHLOROTHIAZIDE', 'TAZAROTENE', 'glycyl-H 1152', 'CHEMBL2337032', 'GLIQUIDONE', 'CHEMBL3348871', 'SITAFLOXACIN HYDRATE', 'MENADIONE', 'DANUSERTIB (PHA-739358)', 'GSK583', 'ZINC139045355', nan, 'KS-00001D5I', 'CLEVIDIPINE BUTYRATE', 'TIMOLOL MALEATE', 'CHEMBL3348955', 'WZ4003', 'AMITRIPTYLINE HCL', 'METHENAMINE', 'Ciliobrevin D', 'SB-747651A', 'Zuclomiphene', 'Ceftiofur', 'CHEMBL3185999', 'CTEP (RO4956371)', 'TYRPHOSTIN AG 879', 'PROGESTERONE', 'RIFAPENTINE', 'MEPENZOLATE BROMIDE', 'I ...
# ------------------------------
# ❌ Found 31 cell lines missing from reference table:
# {'JHH-136', 'HDLM-2', '3D7', 'SMS-CTR', 'UWB1289+BRCA1', 'JHH-520', 'CTR', 'L-428', 'KB-3-1', 'TC-71', 'KB-ChR-8-5-11', 'HB3', 'EW-8', 'Huh-7', 'KBM-7', 'TC-32', 'A-673', 'DIPG25', 'ED-40515', 'MDA-MB-231', 'T98G', 'U-HO1', 'A549', 'NCI\\\\/ADR-RES', 'PANC-1', 'DD2', 'Rh36', 'SU-DIPG-XIII', 'RD', 'L-1236', 'Mak'}

# %%
cell_lines = cell_lines.dropna(subset=['cellName', 'cosmicId'])
drugs = drugs.dropna(subset=['drugName', 'cIds'])

# %%
import sqlite3


drug_combs.columns = ["id", "drug1", "drug2", "cell_line", "zip", "bliss", "loewe", "hsa", "classification"]

# Add a status column to track whether the combination has been processed
drug_combs["status"] = "pending"
    
with sqlite3.connect("./data/drugcombs.sqlite") as conn:
    drug_combs.to_sql("drug_combinations", conn, if_exists="replace", index=False)
    cell_lines.to_sql("cell_lines", conn, if_exists="replace", index=False)
    drugs.to_sql("drugs", conn, if_exists="replace", index=False)
